# %%
import pandas as pd
import ixmp
import message_ix

from message_ix.util import make_df
# %matplotlib inline

# %%
# connection to a database for storing model input data and scenario results
mp = ixmp.Platform()

scenario = message_ix.Scenario(mp, model="West China storage", scenario="baseline", version="new")
# Out:
# ---------------------------------------------------------------------------
# java.net.ConnectException                 Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:540, in oracle.jdbc.driver.T4CConnection.logon()
#
# File T4CConnection.java:1481, in oracle.jdbc.driver.T4CConnection.connect()
#
# File NSProtocol.java:287, in oracle.net.ns.NSProtocol.connect()
#
# File NSProtocol.java:660, in oracle.net.ns.NSProtocol.establishConnection()
#
# File AddrResolution.java:521, in oracle.net.resolver.AddrResolution.resolveAndExecute()
#
# File ConnStrategy.java:508, in oracle.net.nt.ConnStrategy.execute()
#
# File ConnOption.java:172, in oracle.net.nt.ConnOption.connect()
#
# File TcpNTAdapter.java:188, in oracle.net.nt.TcpNTAdapter.connect()
#
# File TimeoutSocketChannel.java:86, in oracle.net.nt.TimeoutSocketChannel.<init>()
#
# File TimeoutSocketChannel.java:108, in oracle.net.nt.TimeoutSocketChannel.connect()
#
# File SocketChannel.java:285, in java.nio.channels.SocketChannel.open()
#
# File SocketChannelImpl.java:853, in sun.nio.ch.SocketChannelImpl.connect()
#
# File Net.java:586, in sun.nio.ch.Net.connect()
#
# File Net.java:579, in sun.nio.ch.Net.connect()
#
# File Net.java:-2, in sun.nio.ch.Net.connect0()
#
# java.net.ConnectException: java.net.ConnectException: Connection timed out: connect
#
# The above exception was the direct cause of the following exception:
#
# java.io.IOException                       Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:540, in oracle.jdbc.driver.T4CConnection.logon()
#
# File T4CConnection.java:1481, in oracle.jdbc.driver.T4CConnection.connect()
#
# File NSProtocol.java:287, in oracle.net.ns.NSProtocol.connect()
#
# File NSProtocol.java:660, in oracle.net.ns.NSProtocol.establishConnection()
#
# File AddrResolution.java:521, in oracle.net.resolver.AddrResolution.resolveAndExecute()
#
# File ConnStrategy.java:508, in oracle.net.nt.ConnStrategy.execute()
#
# File ConnOption.java:172, in oracle.net.nt.ConnOption.connect()
#
# File TcpNTAdapter.java:229, in oracle.net.nt.TcpNTAdapter.connect()
#
# java.io.IOException: java.io.IOException: Connection timed out: connect, socket connect lapse 21038 ms. /147.125.82.88 1521 30000 1 true
#
# The above exception was the direct cause of the following exception:
#
# oracle.net.ns.NetException                Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:540, in oracle.jdbc.driver.T4CConnection.logon()
#
# File T4CConnection.java:1481, in oracle.jdbc.driver.T4CConnection.connect()
#
# File NSProtocol.java:287, in oracle.net.ns.NSProtocol.connect()
#
# File NSProtocol.java:660, in oracle.net.ns.NSProtocol.establishConnection()
#
# File AddrResolution.java:521, in oracle.net.resolver.AddrResolution.resolveAndExecute()
#
# File ConnStrategy.java:569, in oracle.net.nt.ConnStrategy.execute()
#
# oracle.net.ns.NetException: oracle.net.ns.NetException: The Network Adapter could not establish the connection
#
# The above exception was the direct cause of the following exception:
#
# java.sql.SQLRecoverableException          Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:801, in oracle.jdbc.driver.T4CConnection.logon()
#
# java.sql.SQLRecoverableException: java.sql.SQLRecoverableException: IO 错误: The Network Adapter could not establish the connection
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:581, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:595, in com.zaxxer.hikari.pool.HikariPool.throwPoolInitializationException()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# com.zaxxer.hikari.pool.HikariPool.PoolInitializationExceptionTraceback (most recent call last)
# File C:\Anaconda3\envs\message_storage\lib\site-packages\ixmp\backend\jdbc.py:269, in JDBCBackend.__init__(self, jvmargs, **kwargs)
#     268 try:
# --> 269     self.jobj = java.Platform("Python", properties)
#     270 except java.NoClassDefFoundError as e:  # pragma: no cover
#
# com.zaxxer.hikari.pool.HikariPool.PoolInitializationException: com.zaxxer.hikari.pool.HikariPool$PoolInitializationException: Failed to initialize pool: IO 错误: The Network Adapter could not establish the connection
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # connection to a database for storing model input data and scenario results
# ----> 2 mp = ixmp.Platform()
#       4 scenario = message_ix.Scenario(mp, model="West China storage", scenario="baseline", version="new")
#
# File C:\Anaconda3\envs\message_storage\lib\site-packages\ixmp\core\platform.py:92, in Platform.__init__(self, name, backend, **backend_args)
#      86     raise ValueError(
#      87         f"backend class {repr(backend_class_name)} not among "
#      88         + str(sorted(BACKENDS.keys()))
#      89     )
#      91 # Instantiate the backend
# ---> 92 self._backend = backend_class(**kwargs)
#
# File C:\Anaconda3\envs\message_storage\lib\site-packages\ixmp\backend\jdbc.py:292, in JDBCBackend.__init__(self, jvmargs, **kwargs)
#     290     else:
#     291         _raise_jexception(e)
# --> 292     raise RuntimeError(f"{msg}\n(Java: {jclass})")
#     294 # Set the log level
#     295 self.set_log_level(log_level)
#
# RuntimeError: unable to connect to database:
# {'driver': 'oracle', 'url': 'x8oda.iiasa.ac.at:1521/PIXMP1.iiasa.ac.at', 'user': '(HIDDEN)', 'password': '(HIDDEN)'}
# (Java: com.zaxxer.hikari.pool.HikariPool.PoolInitializationException)

# %%
# connection to a database for storing model input data and scenario results
mp = ixmp.Platform()

scenario = message_ix.Scenario(mp, model="Westeros Electrified", scenario="baseline", version="new")
# Out:
# ---------------------------------------------------------------------------
# java.net.ConnectException                 Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:540, in oracle.jdbc.driver.T4CConnection.logon()
#
# File T4CConnection.java:1481, in oracle.jdbc.driver.T4CConnection.connect()
#
# File NSProtocol.java:287, in oracle.net.ns.NSProtocol.connect()
#
# File NSProtocol.java:660, in oracle.net.ns.NSProtocol.establishConnection()
#
# File AddrResolution.java:521, in oracle.net.resolver.AddrResolution.resolveAndExecute()
#
# File ConnStrategy.java:508, in oracle.net.nt.ConnStrategy.execute()
#
# File ConnOption.java:172, in oracle.net.nt.ConnOption.connect()
#
# File TcpNTAdapter.java:188, in oracle.net.nt.TcpNTAdapter.connect()
#
# File TimeoutSocketChannel.java:86, in oracle.net.nt.TimeoutSocketChannel.<init>()
#
# File TimeoutSocketChannel.java:108, in oracle.net.nt.TimeoutSocketChannel.connect()
#
# File SocketChannel.java:285, in java.nio.channels.SocketChannel.open()
#
# File SocketChannelImpl.java:853, in sun.nio.ch.SocketChannelImpl.connect()
#
# File Net.java:586, in sun.nio.ch.Net.connect()
#
# File Net.java:579, in sun.nio.ch.Net.connect()
#
# File Net.java:-2, in sun.nio.ch.Net.connect0()
#
# java.net.ConnectException: java.net.ConnectException: Connection timed out: connect
#
# The above exception was the direct cause of the following exception:
#
# java.io.IOException                       Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:540, in oracle.jdbc.driver.T4CConnection.logon()
#
# File T4CConnection.java:1481, in oracle.jdbc.driver.T4CConnection.connect()
#
# File NSProtocol.java:287, in oracle.net.ns.NSProtocol.connect()
#
# File NSProtocol.java:660, in oracle.net.ns.NSProtocol.establishConnection()
#
# File AddrResolution.java:521, in oracle.net.resolver.AddrResolution.resolveAndExecute()
#
# File ConnStrategy.java:508, in oracle.net.nt.ConnStrategy.execute()
#
# File ConnOption.java:172, in oracle.net.nt.ConnOption.connect()
#
# File TcpNTAdapter.java:229, in oracle.net.nt.TcpNTAdapter.connect()
#
# java.io.IOException: java.io.IOException: Connection timed out: connect, socket connect lapse 21056 ms. /147.125.82.88 1521 30000 1 true
#
# The above exception was the direct cause of the following exception:
#
# oracle.net.ns.NetException                Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:540, in oracle.jdbc.driver.T4CConnection.logon()
#
# File T4CConnection.java:1481, in oracle.jdbc.driver.T4CConnection.connect()
#
# File NSProtocol.java:287, in oracle.net.ns.NSProtocol.connect()
#
# File NSProtocol.java:660, in oracle.net.ns.NSProtocol.establishConnection()
#
# File AddrResolution.java:521, in oracle.net.resolver.AddrResolution.resolveAndExecute()
#
# File ConnStrategy.java:569, in oracle.net.nt.ConnStrategy.execute()
#
# oracle.net.ns.NetException: oracle.net.ns.NetException: The Network Adapter could not establish the connection
#
# The above exception was the direct cause of the following exception:
#
# java.sql.SQLRecoverableException          Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:560, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:477, in com.zaxxer.hikari.pool.HikariPool.createPoolEntry()
#
# File PoolBase.java:206, in com.zaxxer.hikari.pool.PoolBase.newPoolEntry()
#
# File PoolBase.java:358, in com.zaxxer.hikari.pool.PoolBase.newConnection()
#
# File DriverDataSource.java:138, in com.zaxxer.hikari.util.DriverDataSource.getConnection()
#
# File OracleDriver.java:704, in oracle.jdbc.driver.OracleDriver.connect()
#
# File T4CDriverExtension.java:39, in oracle.jdbc.driver.T4CDriverExtension.getConnection()
#
# File PhysicalConnection.java:782, in oracle.jdbc.driver.PhysicalConnection.connect()
#
# File T4CConnection.java:801, in oracle.jdbc.driver.T4CConnection.logon()
#
# java.sql.SQLRecoverableException: java.sql.SQLRecoverableException: IO 错误: The Network Adapter could not establish the connection
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# File Platform.java:110, in at.ac.iiasa.ixmp.Platform.<init>()
#
# File Platform.java:163, in at.ac.iiasa.ixmp.Platform.initPlatform()
#
# File DbDAO.java:239, in at.ac.iiasa.ixmp.database.DbDAO.create()
#
# File DbDAO.java:2690, in at.ac.iiasa.ixmp.database.DbDAO.openConn()
#
# File DbDAO.java:216, in at.ac.iiasa.ixmp.database.DbDAO.initDataSource()
#
# File HikariDataSource.java:81, in com.zaxxer.hikari.HikariDataSource.<init>()
#
# File HikariPool.java:115, in com.zaxxer.hikari.pool.HikariPool.<init>()
#
# File HikariPool.java:581, in com.zaxxer.hikari.pool.HikariPool.checkFailFast()
#
# File HikariPool.java:595, in com.zaxxer.hikari.pool.HikariPool.throwPoolInitializationException()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# com.zaxxer.hikari.pool.HikariPool.PoolInitializationExceptionTraceback (most recent call last)
# File C:\Anaconda3\envs\message_storage\lib\site-packages\ixmp\backend\jdbc.py:269, in JDBCBackend.__init__(self, jvmargs, **kwargs)
#     268 try:
# --> 269     self.jobj = java.Platform("Python", properties)
#     270 except java.NoClassDefFoundError as e:  # pragma: no cover
#
# com.zaxxer.hikari.pool.HikariPool.PoolInitializationException: com.zaxxer.hikari.pool.HikariPool$PoolInitializationException: Failed to initialize pool: IO 错误: The Network Adapter could not establish the connection
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 # connection to a database for storing model input data and scenario results
# ----> 2 mp = ixmp.Platform()
#       4 scenario = message_ix.Scenario(mp, model="Westeros Electrified", scenario="baseline", version="new")
#
# File C:\Anaconda3\envs\message_storage\lib\site-packages\ixmp\core\platform.py:92, in Platform.__init__(self, name, backend, **backend_args)
#      86     raise ValueError(
#      87         f"backend class {repr(backend_class_name)} not among "
#      88         + str(sorted(BACKENDS.keys()))
#      89     )
#      91 # Instantiate the backend
# ---> 92 self._backend = backend_class(**kwargs)
#
# File C:\Anaconda3\envs\message_storage\lib\site-packages\ixmp\backend\jdbc.py:292, in JDBCBackend.__init__(self, jvmargs, **kwargs)
#     290     else:
#     291         _raise_jexception(e)
# --> 292     raise RuntimeError(f"{msg}\n(Java: {jclass})")
#     294 # Set the log level
#     295 self.set_log_level(log_level)
#
# RuntimeError: unable to connect to database:
# {'driver': 'oracle', 'url': 'x8oda.iiasa.ac.at:1521/PIXMP1.iiasa.ac.at', 'user': '(HIDDEN)', 'password': '(HIDDEN)'}
# (Java: com.zaxxer.hikari.pool.HikariPool.PoolInitializationException)
